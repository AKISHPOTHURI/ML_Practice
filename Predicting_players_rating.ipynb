# %% [markdown]
# player_fifa_api_id : the id used for the players on the sofifa.com web site
#
# player_api_id : The "player_api_id" will be used to join the Match and Player tables.
#
# overall_rating : Average of all rating
#
# potential : potential of the player
#
# preferred_foot : preferred foot shot the goal.
#
# attacking_work_rate : taking the chance of shooting the goal.
#
# defensive_work_rate : Taking the chance or tried to stop the goal of opponent team.
#
# Crossing : cross is to directly bring the ball into the box from an angle that allows the attacking forwards to more easily aim for goal with their head or feet.
#
# Finishing : scoring goal
#
# heading : A player hits the ball with their head to move it in a certain direction
#
# short_passing : Passing the ball to another player in ground.
#
# volleys : where a player's foot meets and directs the ball in an angled direction before it has time to reach the ground.
#
# dribbling : staying on the ball while moving it around the pitch.
#
# curve : spin on the ball which makes the ball move in a curved direction
#
# free_kick : the free kick is a method of restarting the game following an offence by the opposing side.
#
# long_passing : A ground pass longer than 45 meters or a high pass longer than 25 meters.
#
# ball control : ball control could be stationary trapping a pass perfectly from the air then playing it to a teammate quickly.
#
# acceleration : the rate of change of velocity, or how quickly an athlete can increase the velocity of the motion.
#
# sprint_speed : sprints involve lots of short, rapid bursts of acceleration.
#
# agility : Like speed, ability to stop, start and change direction
#
# reaction : Having a quick reaction time allows a sprinter to start running the moment a race begins, and a football player to avoid a tackle.
#
# balance : being able to throw the ball effectively on third and long or run it on third and short.
#
# shot_power : strength of a player's shootings.
#
# long shot : shot the goal from long distance
#
# aggression : Aggression in the game or aggression to shot a goal.
#
# interceptions : describe a defensive player who takes possession of the ball after it has been thrown or kicked by the opposing team.
#
# positioning : a style of play where the football pitch is divided into zones and each player is assigned to a zone.
#
# vision : eye sight
#
# penalties : when a defending team commits a foul or a handball inside its own penalty box, the opposition side is awarded with a penalty or penalty kick.
#
# marking : Man-to-man marking, or man marking, is a defensive strategy where defenders are assigned a specific opposition player
#
# Tackling('standing_tackle' & 'sliding_tackle') : Tackling is about winning the ball from an opponent.
#
# gk_reflex : player's ability and speed to react (reflex) for catching/saving the ball as a goalkeeper.
#
# gk_diving : makes a dive parallel to the ground to reach the ball faster(goal keeper).
#
# gk_handling : determines a player's ability to handle the ball and hold onto it using their hands as a goalkeeper.
#
# gk_kicking : gk kicking the ball when goal shot by the player.
#
# gk_positioning : Position of the gk when player shoting the ball.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
import sqlite3
import pandas as pd
conn = sqlite3.connect('/content/drive/MyDrive/ML_Assignments/database.sqlite')
cursor = conn.cursor()
df = pd.read_sql_query("SELECT * FROM Player_Attributes", conn)

# %%
df.head()
# Out:
#    id  player_fifa_api_id  player_api_id                 date  overall_rating  \
# 0   1              218353         505942  2016-02-18 00:00:00            67.0
# 1   2              218353         505942  2015-11-19 00:00:00            67.0
# 2   3              218353         505942  2015-09-21 00:00:00            62.0
# 3   4              218353         505942  2015-03-20 00:00:00            61.0
# 4   5              218353         505942  2007-02-22 00:00:00            61.0
#
#    potential preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0       71.0          right              medium              medium      49.0
# 1       71.0          right              medium              medium      49.0
# 2       66.0          right              medium              medium      49.0
# 3       65.0          right              medium              medium      48.0
# 4       65.0          right              medium              medium      48.0
#
# ...

# %%
import numpy as np
np.array(df.head(1))
# Out:
# array([[1, 218353, 505942, '2016-02-18 00:00:00', 67.0, 71.0, 'right',
#         'medium', 'medium', 49.0, 44.0, 71.0, 61.0, 44.0, 51.0, 45.0,
#         39.0, 64.0, 49.0, 60.0, 64.0, 59.0, 47.0, 65.0, 55.0, 58.0, 54.0,
#         76.0, 35.0, 71.0, 70.0, 45.0, 54.0, 48.0, 65.0, 69.0, 69.0, 6.0,
#         11.0, 10.0, 8.0, 8.0]], dtype=object)

# %%
df.columns
# Out:
# Index(['id', 'player_fifa_api_id', 'player_api_id', 'date', 'overall_rating',
#        'potential', 'preferred_foot', 'attacking_work_rate',
#        'defensive_work_rate', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# id                        0
# player_fifa_api_id        0
# player_api_id             0
# date                      0
# overall_rating          836
# potential               836
# preferred_foot          836
# attacking_work_rate    3230
# defensive_work_rate     836
# crossing                836
# finishing               836
# heading_accuracy        836
# short_passing           836
# volleys                2713
# dribbling               836
# curve                  2713
# free_kick_accuracy      836
# long_passing            836
# ball_control            836
# acceleration            836
# sprint_speed            836
# agility                2713
# reactions               836
# balance                2713
# shot_power              836
# jumping                2713
# stamina                 836
# strength                836
# long_shots              836
# aggression              836
# interceptions           836
# positioning             836
# vision                 2713
# ...

# %%
df.shape
# Out:
# (183978, 42)

# %%
# Drop the NULL rows
#Approciatemetly about 2 percent data is erased. It will not effect the final decision.
df = df.dropna()

# %%
df.shape
# Out:
# (180354, 42)

# %%
((183978 - 180354)/(183978))*100
# Out:
# 1.9698007370446464

# %%
df.isnull().sum()
# Out:
# id                     0
# player_fifa_api_id     0
# player_api_id          0
# date                   0
# overall_rating         0
# potential              0
# preferred_foot         0
# attacking_work_rate    0
# defensive_work_rate    0
# crossing               0
# finishing              0
# heading_accuracy       0
# short_passing          0
# volleys                0
# dribbling              0
# curve                  0
# free_kick_accuracy     0
# long_passing           0
# ball_control           0
# acceleration           0
# sprint_speed           0
# agility                0
# reactions              0
# balance                0
# shot_power             0
# jumping                0
# stamina                0
# strength               0
# long_shots             0
# aggression             0
# interceptions          0
# positioning            0
# vision                 0
# penalties              0
# marking                0
# standing_tackle        0
# sliding_tackle         0
# ...

# %%
df.describe()
# Out:
#                   id  player_fifa_api_id  player_api_id  overall_rating  \
# count  180354.000000       180354.000000  180354.000000   180354.000000
# mean    91995.886274       166822.125803  137653.145514       68.635317
# std     53092.657914        52821.443279  137599.735284        7.027950
# min         1.000000            2.000000    2625.000000       33.000000
# 25%     46074.250000       156616.000000   35451.000000       64.000000
# 50%     92003.500000       183792.000000   80291.000000       69.000000
# 75%    137935.750000       200138.000000  192841.000000       73.000000
# max    183978.000000       234141.000000  750584.000000       94.000000
#
#            potential       crossing      finishing  heading_accuracy  \
# count  180354.000000  180354.000000  180354.000000     180354.000000
# mean       73.479457      55.142071      49.962136         57.263476
# std         6.581963      17.247231      19.041760         16.478716
# ...

# %%
df.corr()
# Out:
# <ipython-input-14-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                           id  player_fifa_api_id  player_api_id  \
# id                  1.000000            0.003744       0.002048
# player_fifa_api_id  0.003744            1.000000       0.556557
# player_api_id       0.002048            0.556557       1.000000
# overall_rating     -0.003738           -0.278703      -0.328315
# potential           0.000837           -0.021252       0.010588
# crossing           -0.020231           -0.065631      -0.113365
# finishing          -0.008171           -0.029836      -0.062312
# heading_accuracy   -0.011781           -0.103500      -0.130282
# short_passing      -0.006701           -0.065311      -0.090237
# volleys            -0.006916           -0.088726      -0.131262
# ...

# %%
# import seaborn as sns
#plotting the heatmap for correlation
# ax = sns.heatmap(df.corr(), annot=True)

# %%
# sns.displot(data=df, x="potential", kind="kde")

# %%
import numpy as np
numeric_data = df.select_dtypes(include=[np.number])
# for i in numeric_data:
#   sns.displot(data=df, x=i, kind="kde")

# %%
# sns.lineplot(data=df, x="potential", y="overall_rating")

# %%
numeric_data.columns
# Out:
# Index(['id', 'player_fifa_api_id', 'player_api_id', 'overall_rating',
#        'potential', 'crossing', 'finishing', 'heading_accuracy',
#        'short_passing', 'volleys', 'dribbling', 'curve', 'free_kick_accuracy',
#        'long_passing', 'ball_control', 'acceleration', 'sprint_speed',
#        'agility', 'reactions', 'balance', 'shot_power', 'jumping', 'stamina',
#        'strength', 'long_shots', 'aggression', 'interceptions', 'positioning',
#        'vision', 'penalties', 'marking', 'standing_tackle', 'sliding_tackle',
#        'gk_diving', 'gk_handling', 'gk_kicking', 'gk_positioning',
#        'gk_reflexes'],
#       dtype='object')

# %%
categorical_data = df.select_dtypes(exclude=[np.number])

# %%
categorical_data.columns
# Out:
# Index(['date', 'preferred_foot', 'attacking_work_rate', 'defensive_work_rate'], dtype='object')

# %%
df['preferred_foot'].unique()
# Out:
# array(['right', 'left'], dtype=object)

# %%
df['attacking_work_rate'].unique()
# Out:
# array(['medium', 'high', 'low', 'None', 'le', 'norm', 'stoc', 'y'],
#       dtype=object)

# %%
df['defensive_work_rate'].unique()
# Out:
# array(['medium', 'high', 'low', '5', 'ean', 'o', '1', 'ormal', '7', '2',
#        '8', '4', 'tocky', '0', '3', '6', '9', 'es'], dtype=object)

# %%
preferred_foot_map = {'right':1, 'left':2}
attacking_work_rate_map = {'None':0,'medium':1, 'high':2, 'low':3,'le':4, 'norm':5, 'stoc':6, 'y':7}
defensive_work_rate_map = {'medium':1, 'high':2, 'low':3, '5':4, 'ean':5, 'o':6, '1':7, 'ormal':8, '7':9, '2':10,
       '8':11, '4':12, 'tocky':13, '0':14, '3':15, '6':16, '9':17, 'es':18}

# %%
df['preferred_foot'] = df['preferred_foot'].replace(preferred_foot_map)
df['attacking_work_rate'] = df['attacking_work_rate'].replace(attacking_work_rate_map)
df['defensive_work_rate'] = df['defensive_work_rate'].replace(defensive_work_rate_map)

# %%
df = df.drop(columns = ['date','id', 'player_fifa_api_id', 'player_api_id'])

# %%
df.head()
# Out:
#    overall_rating  potential  preferred_foot  attacking_work_rate  \
# 0            67.0       71.0               1                    1
# 1            67.0       71.0               1                    1
# 2            62.0       66.0               1                    1
# 3            61.0       65.0               1                    1
# 4            61.0       65.0               1                    1
#
#    defensive_work_rate  crossing  finishing  heading_accuracy  short_passing  \
# 0                    1      49.0       44.0              71.0           61.0
# 1                    1      49.0       44.0              71.0           61.0
# 2                    1      49.0       44.0              71.0           61.0
# 3                    1      48.0       43.0              70.0           60.0
# 4                    1      48.0       43.0              70.0           60.0
#
#    volleys  ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
X = df.drop(columns = ['overall_rating'])
y = df.overall_rating

# %%
X.head()
# Out:
#    potential  preferred_foot  attacking_work_rate  defensive_work_rate  \
# 0       71.0               1                    1                    1
# 1       71.0               1                    1                    1
# 2       66.0               1                    1                    1
# 3       65.0               1                    1                    1
# 4       65.0               1                    1                    1
#
#    crossing  finishing  heading_accuracy  short_passing  volleys  dribbling  \
# 0      49.0       44.0              71.0           61.0     44.0       51.0
# 1      49.0       44.0              71.0           61.0     44.0       51.0
# 2      49.0       44.0              71.0           61.0     44.0       51.0
# 3      48.0       43.0              70.0           60.0     43.0       50.0
# 4      48.0       43.0              70.0           60.0     43.0       50.0
#
#    ...  vision  penalties  marking  standing_tackle  sliding_tackle  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=32)

# %% [markdown]
# From pattern of above data we can assume that, Problem will be solved using regression algorithms.
#
# There are Four major Regression Algorithms:
#
# Linear Regression -> Lasso, Ridge, Elastinet
#
# Decision Tree Regresser
#
# Support Vector Regressor
#
# Random Forest Regressor

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
import numpy as np
def evaluate_model(true, predicted):
    mae = mean_absolute_error(true, predicted)
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mean_squared_error(true, predicted))
    r2_square = r2_score(true, predicted)
    return mae, rmse, r2_square

# %%
## Train multiple models
from sklearn.metrics import accuracy_score
models={
    'LinearRegression':LinearRegression(),
    'Lasso':Lasso(),
    'Ridge':Ridge(),
    'Elasticnet':ElasticNet()
}
trained_model_list=[]
model_list=[]
r2_list=[]

for i in range(len(list(models))):
    model=list(models.values())[i]
    model.fit(X_train,y_train)

    #Make Predictions
    y_pred=model.predict(X_test)

    mae, rmse, r2_square=evaluate_model(y_test,y_pred)

    print(list(models.keys())[i])
    model_list.append(list(models.keys())[i])

    print('Model Training Performance')
    print("RMSE:",rmse)
    print("MAE:",mae)
    print("R2 score",r2_square*100)

    r2_list.append(r2_square)

    print('='*35)
    # print('\n')
# Out:
# LinearRegression
# Model Training Performance
# RMSE: 2.78517069013605
# MAE: 2.133430397493354
# R2 score 84.42275719520062
# ...
# Lasso
# Model Training Performance
# RMSE: 2.8303560596337376
# MAE: 2.165242618976867
# R2 score 83.91322070019898
# ...
# Ridge
# Model Training Performance
# RMSE: 2.7851706847674795
# MAE: 2.1334303756186466
# R2 score 84.4227572552526
# ...
# Elasticnet
# Model Training Performance
# RMSE: 2.809748220769611
# MAE: 2.151809764353381
# R2 score 84.14662375755724
# ...

# %%
#Ridge rocks here
model.intercept_
# Out:
# -1.4523310767990125

# %%
model.coef_
# Out:
# array([ 3.73414242e-01, -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         1.76134718e-02,  3.00100738e-03,  6.63648260e-02,  4.29413581e-02,
#         4.96905861e-04,  0.00000000e+00,  8.59984389e-03,  8.81141968e-03,
#         6.63790163e-03,  1.19903399e-01,  2.28248888e-04,  1.64760146e-03,
#        -0.00000000e+00,  2.14955361e-01,  0.00000000e+00,  1.29289704e-02,
#         1.58912620e-02, -0.00000000e+00,  5.91637865e-02, -0.00000000e+00,
#         1.87768591e-02,  8.22988962e-03, -7.35254682e-04,  0.00000000e+00,
#         1.18600888e-02,  1.90170373e-02,  0.00000000e+00, -9.34268412e-03,
#         1.67736839e-01,  2.14374746e-02, -2.31135451e-02,  4.36265849e-02,
#         1.77566239e-02])

# %%
from sklearn import tree
alphas = []
model = tree.DecisionTreeRegressor(random_state=0)
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
tree_para = [{'criterion': ['squared_error','friedman_mse','absolute_error','poisson'],
              'max_depth': range(2,60),
              'max_features': ['sqrt', 'log2', None],
              'splitter': ['best', 'random']}]

# %%
tree_para
# Out:
# [{'criterion': ['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
#   'max_depth': range(2, 60),
#   'max_features': ['sqrt', 'log2', None],
#   'splitter': ['best', 'random']}]

# %%
model = tree.DecisionTreeRegressor(ccp_alpha=0.005,max_features='log2')
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.005, max_features='log2')

# %%
y_pred = model.predict(X_test)
mae, rmse, r2_square=evaluate_model(y_test,y_pred)

# %%
print(mae,rmse,r2_square)
# Out:
# 1.9112919077852843 2.537947547048042 0.8706542268491945

# %%
from sklearn.svm import SVR
regressor = SVR(kernel = 'rbf')
regressor.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred = regressor.predict(X_test)
mae, rmse, r2_square=evaluate_model(y_test,y_pred)
print(mae,rmse,r2_square)
# Out:
# 0.8327285758793569 1.2249485102076656 0.9698683700877561

# %%
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.model_selection import GridSearchCV
# ## Define Grid
# grid = {
#     'n_estimators': [200,300,400,500],
#     'max_features': ['sqrt','log2'],
#     'max_depth' : [3,4,5,6,7],
#     'random_state' : [18]
# }
# ## show start time
# # print(datetime.now())

# ## Grid Search function
# CV_rfr = GridSearchCV(estimator=RandomForestRegressor(), param_grid=grid, cv= 5)
# CV_rfr.fit(X_train, y_train)

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = regressor.predict(X_test)
mae, rmse, r2_square=evaluate_model(y_test,y_pred)
print(mae,rmse,r2_square)
# Out:
# 0.8327285758793569 1.2249485102076656 0.9698683700877561
